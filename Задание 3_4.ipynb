# %%
x = {}

x[1] = 10
x['abc'] = 'def'
x[0] = [0,1,2]
x[(0,1)] = 'a'

y = [0,1,2]
y.append(3)
y.pop(0)

x[1] = 10+5
x['abc'] = 'def'+'def'
x[0] = y
x.pop((0,1))

print(x)
print()
print()
# Out:
# {1: 15, 'abc': 'defdef', 0: [1, 2, 3]}
